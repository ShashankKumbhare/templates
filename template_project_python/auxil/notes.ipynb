# %%
import template_pkg as temp
# Out:
# ...
# Importing package 'template_pkg'...
# ...
#
#  + Adding subpackage '__dependencies_subpkg__'...
#    + Adding submodule '__dependencies_subpkg__._dependencies_submod'...
#    - Done!
#  - Done!
#
#  + Adding subpackage '__constants_subpkg__'...
#    + Adding submodule '__constants_subpkg__._constants_submod'...
#    - Done!
#  - Done!
#
#  + Adding subpackage '__auxil_subpkg__'...
#    + Adding submodule '__auxil_subpkg__._auxil_submod'...
#    - Done!
#  - Done!
#
# ...
# Package 'template_pkg' imported sucessfully !!
# ...

# %%
temp.

# %%
print("shashank.", end="")
print("kumbhare")
# Out:
# shashank.kumbhare

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#     |   |
#     |   +----_template_submod.py
#     |   |
#     |   +----_template_submod.py
#     |
#     +---auxil_subpkg
#     |   |
#     |   +---_auxil_submod.py
#     |   |
#     |   +----_template_submod.py
#     |
#     +---constants_subpkg
#     |   |
#     |   +---_constants_submod.py
#     |   |
#     |   +----_template_submod.py
#     |
#     +---dependencies_subpkg
#         |
#         +---_dependencies_submod.py
#         |
#         +----_template_submod.py
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#     |   +----_template_submod.py
#     |   +----_template_submod.py
#     |
#     +---auxil_subpkg
#     |   +---_auxil_submod.py
#     |   +----_template_submod.py
#     |
#     +---constants_subpkg
#     |   +---_constants_submod.py
#     |   +----_template_submod.py
#     |
#     +---dependencies_subpkg
#         +---_dependencies_submod.py
#         +----_template_submod.py
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#     |-------template_submod.py
#     |-------template_submod.py
#     |
#     +---auxil_subpkg
#     |-------auxil_submod.py
#     |-------template_submod.py
#     |
#     +---constants_subpkg
#     |-------constants_submod.py
#     |-------template_submod.py
#     |
#     +---dependencies_subpkg
#     |-------dependencies_submod.py
#     |-------template_submod.py
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#     |-------template_submod.py... Done !!
#     |-------template_submod.py... Done !!
#     |
#     +---auxil_subpkg
#     |-------auxil_submod.py --- Done !!
#     |-------template_submod.py --- Done !!
#     |
#     +---constants_subpkg
#     |-------constants_submod.py ... Done !!
#     |-------template_submod.py ... Done !!
#     |
#     +---dependencies_subpkg
#     |-------dependencies_submod.py ---> Done !!
#     |-------template_submod.py ---> Done !!
#     |
#     +---dependencies_subpkg
#     |-------dependencies_submod.py   Done !!
#     |-------template_submod.py   Done !!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#     |-------template_submod.py ... Done !!
#     |-------template_submod.py ... Done !!
#     |
#     +---auxil_subpkg
#     |-------auxil_submod.py ... Done !!
#     |-------template_submod.py ... Done !!
#     |
#     +---constants_subpkg
#     |-------constants_submod.py ... Done !!
#     |-------template_submod.py ... Done !!
#     |
#     +---dependencies_subpkg
#     |-------dependencies_submod.py ... Done !!
#     |-------template_submod.py ... Done !!
#     |
#     +---dependencies_subpkg
#     |-------dependencies_submod.py ... Done !!
#     |-------template_submod.py ... Done !!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#     |   |---template_submod.py ... Done !!
#     |   |---template_submod.py ... Done !!
#     |
#     +---auxil_subpkg
#     |   |---auxil_submod.py ... Done !!
#     |   |---template_submod.py ... Done !!
#     |
#     +---constants_subpkg
#     |   |---constants_submod.py ... Done !!
#     |   |---template_submod.py ... Done !!
#     |
#     +---dependencies_subpkg
#     |   |---dependencies_submod.py ... Done !!
#     |   |---template_submod.py ... Done !!
#     |
#     +---dependencies_subpkg
#     |   |---dependencies_submod.py ... Done !!
#     |   |---template_submod.py ... Done !!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#     |   +---template_submod.py ... Done !!
#     |   +---template_submod.py ... Done !!
#     |
#     +---auxil_subpkg
#     |   +---auxil_submod.py ... Done !!
#     |   +---template_submod.py ... Done !!
#     |
#     +---constants_subpkg
#     |   +---constants_submod.py ... Done !!
#     |   +---template_submod.py ... Done !!
#     |
#     +---dependencies_subpkg
#     |   +---dependencies_submod.py ... Done !!
#     |   +---template_submod.py ... Done !!
#     |
#     +---dependencies_subpkg
#         +---dependencies_submod.py ... Done !!
#         +---template_submod.py ... Done !!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#     .   +---template_submod.py ... Done !!
#     .   +---template_submod.py ... Done !!
#     .
#     +---auxil_subpkg
#     .   +---auxil_submod.py ... Done !!
#     .   +---template_submod.py ... Done !!
#     .
#     +---constants_subpkg
#     .   +---constants_submod.py ... Done !!
#     .   +---template_submod.py ... Done !!
#     .
#     +---dependencies_subpkg
#     .   +---dependencies_submod.py ... Done !!
#     .   +---template_submod.py ... Done !!
#     .
#     +---dependencies_subpkg
#         +---dependencies_submod.py ... Done !!
#         +---template_submod.py ... Done !!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +   template_subpkg
#         +   template_submod.py ... Done !!
#         +   template_submod.py ... Done !!
#         ... Done !!
#
#     +   auxil_subpkg
#         +   auxil_submod.py ... Done !!
#         +   template_submod.py ... Done !!
#         ... Done !!
#
#     +   constants_subpkg
#         +   constants_submod.py ... Done !!
#         +   template_submod.py ... Done !!
#         ... Done !!
#
#     +---dependencies_subpkg
#         +   dependencies_submod.py ... Done !!
#         +   template_submod.py ... Done !!
#         ... Done !!
#
#     +   dependencies_subpkg
#         +   dependencies_submod.py ... Done !!
#         +   template_submod.py ... Done !!
#         ... Done !!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_subpkg
#         +---template_submod.py ... Done!
#         +---template_submod.py ... Done!
#         Done!
#
#
#     +---auxil_subpkg
#         +---auxil_submod.py ... Done!
#         +---template_submod.py ... Done!
#         Done!
#
#     +---constants_subpkg
#         +---constants_submod.py ... Done!
#         +---template_submod.py ... Done!
#         Done!
#
#     +---dependencies_subpkg
#         +---dependencies_submod.py ... Done!
#         +---template_submod.py ... Done!
#         Done!
#
#     +---dependencies_subpkg
#         +---dependencies_submod.py ... Done!
#         +---template_submod.py ... Done!
#         Done!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     +---template_pkg
#     |    |
#     |    +---template_subpkg
#     |    |   +---template_submod.py ... Done!
#     |    |   +---template_submod.py ... Done!
#     |    |   Done!
#     |    |
#     |    +---auxil_subpkg
#     |    |   +---auxil_submod.py ... Done!
#     |    |   +---template_submod.py ... Done!
#     |    |   Done!
#     |    |
#     |    +---constants_subpkg
#     |    |   +---constants_submod.py ... Done!
#     |    |   +---template_submod.py ... Done!
#     |    |   Done!
#     |    |
#     |    +---dependencies_subpkg
#     |    |   +---dependencies_submod.py ... Done!
#     |    |   +---template_submod.py ... Done!
#     |    |   Done!
#     |    |
#     |    +---dependencies_subpkg
#     |        +---dependencies_submod.py ... Done!
#     |        +---template_submod.py ... Done!
#     |        Done!
#     |
#     Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     |----template_pkg >> importing...
#     |    |
#     |    |---template_subpkg >> importing...
#     |    |-------template_submod.py >> importing... >> Done!
#     |    |-------template_submod.py >> importing... >> Done!
#     |    |   >> Done!
#     |    |
#     |    |---auxil_subpkg
#     |    |-------auxil_submod.py >> importing... >> Done!
#     |    |-------template_submod.py >> importing... >> Done!
#     |    |   >> Done!
#     |    |
#     |    |---constants_subpkg
#     |    |-------constants_submod.py >> importing... >> Done!
#     |    |-------template_submod.py >> importing... >> Done!
#     |    |   >> Done!
#     |    |
#     |    |---dependencies_subpkg
#     |    |-------dependencies_submod.py >> importing... >> Done!
#     |    |-------template_submod.py >> importing... >> Done!
#     |    |   >> Done!
#     |    |
#     |    |---dependencies_subpkg >> importing... >> Done!
#     |    |-------dependencies_submod.py >> importing... >> Done!
#     |    |-------template_submod.py >> importing... >> Done!
#     |    |   >> Done!
#     |
#     Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     |---template_pkg > importing...
#     |    |
#     |    |---template_subpkg > importing...
#     |    |-------template_submod.py > importing... > Done!
#     |    |-------template_submod.py > importing... > Done!
#     |    |   > Done!
#     |    |
#     |    |---auxil_subpkg
#     |    |-------auxil_submod.py >> importing... > Done!
#     |    |-------template_submod.py >> importing... > Done!
#     |    |   > Done!
#     |    |
#     |    |---constants_subpkg
#     |    |-------constants_submod.py >> importing... > Done!
#     |    |-------template_submod.py >> importing... > Done!
#     |    |   > Done!
#     |    |
#     |    |---dependencies_subpkg
#     |    |-------dependencies_submod.py >> importing... > Done!
#     |    |-------template_submod.py >> importing... > Done!
#     |    |   > Done!
#     |    |
#     |    |---dependencies_subpkg >> importing... > Done!
#     |    |-------dependencies_submod.py >> importing... > Done!
#     |    |-------template_submod.py >> importing... > Done!
#     |    |   > Done!
#     |
#     Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     template_pkg >> importing...
#     |
#     |---- template_subpkg >> importing...
#     |-------- template_submod.py >> importing... >> Done!
#     |-------- template_submod.py >> importing... >> Done!
#     |     >> Done!
#     |
#     |---- auxil_subpkg
#     |-------- auxil_submod.py >> importing... >> Done!
#     |-------- template_submod.py >> importing... >> Done!
#     |     >> Done!
#     |
#     |---- constants_subpkg
#     |-------- constants_submod.py >> importing... >> Done!
#     |-------- template_submod.py >> importing... >> Done!
#     |     >> Done!
#     |
#     |---- dependencies_subpkg
#     |-------- dependencies_submod.py >> importing... >> Done!
#     |-------- template_submod.py >> importing... >> Done!
#     |     >> Done!
#     |
#     |---- dependencies_subpkg >> importing... >> Done!
#     |-------- dependencies_submod.py >> importing... >> Done!
#     |-------- template_submod.py >> importing... >> Done!
#     |     >> Done!
#     |
#     >> Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     template_pkg > importing...
#     |
#     |---- template_subpkg > importing...
#     |-------- template_submod.py > importing... > Done!
#     |-------- template_submod.py > importing... > Done!
#     |     > Done!
#     |
#     |---- auxil_subpkg
#     |-------- auxil_submod.py > importing... > Done!
#     |-------- template_submod.py > importing... > Done!
#     |     > Done!
#     |
#     |---- constants_subpkg
#     |-------- constants_submod.py > importing... > Done!
#     |-------- template_submod.py > importing... > Done!
#     |     > Done!
#     |
#     |---- dependencies_subpkg
#     |-------- dependencies_submod.py > importing... > Done!
#     |-------- template_submod.py > importing... > Done!
#     |     > Done!
#     |
#     |---- dependencies_subpkg > importing... > Done!
#     |-------- dependencies_submod.py > importing... > Done!
#     |-------- template_submod.py > importing... > Done!
#     |     > Done!
#     |
#     >> Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing > template_pkg
#     |
#     |---- importing > template_subpkg
#     |-------- importing > template_submod.py > Done!
#     |-------- importing > template_submod.py > Done!
#     |     > Done!
#     |
#     |---- importing > auxil_subpkg
#     |-------- importing > auxil_submod.py > Done!
#     |-------- importing > template_submod.py > Done!
#     |     > Done!
#     |
#     |---- importing > constants_subpkg
#     |-------- importing > constants_submod.py > Done!
#     |-------- importing > template_submod.py > Done!
#     |     > Done!
#     |
#     |---- importing > dependencies_subpkg
#     |-------- importing > dependencies_submod.py > Done!
#     |-------- importing > template_submod.py > Done!
#     |     > Done!
#     |
#     |---- importing > dependencies_subpkg > Done!
#     |-------- importing > dependencies_submod.py > Done!
#     |-------- importing > template_submod.py > Done!
#     |     > Done!
#     |
#     > Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing - template_pkg
#     |
#     |---- importing - template_subpkg
#     |--------- importing - template_submod.py - Done!
#     |--------- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - auxil_subpkg
#     |--------- importing - auxil_submod.py - Done!
#     |--------- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - constants_subpkg
#     |--------- importing - constants_submod.py - Done!
#     |--------- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - dependencies_subpkg
#     |--------- importing - dependencies_submod.py - Done!
#     |--------- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - dependencies_subpkg
#     |--------- importing - dependencies_submod.py - Done!
#     |--------- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     - Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing - template_pkg
#     |
#     |---- importing - template_subpkg
#     |     |---- importing - template_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - auxil_subpkg
#     |     |---- importing - auxil_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - constants_subpkg
#     |     |---- importing - constants_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - dependencies_subpkg
#     |     |---- importing - dependencies_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - dependencies_subpkg
#     |     |---- importing - dependencies_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     - Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing - template_pkg
#     |
#     |---- importing - template_subpkg
#     |     |---- importing - template_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - auxil_subpkg
#     |     |---- importing - auxil_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - constants_subpkg
#     |     |---- importing - constants_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - dependencies_subpkg
#     |     |---- importing - dependencies_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---- importing - dependencies_subpkg
#     |     |---- importing - dependencies_submod.py - Done!
#     |     |---- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     - Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing - template_pkg
#     |
#     |-- importing - template_subpkg
#     |   |-- importing - template_submod.py - Done!
#     |   |-- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |-- importing - auxil_subpkg
#     |   |-- importing - auxil_submod.py - Done!
#     |   |-- importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |-- importing - constants_subpkg
#     |   |-- importing - constants_submod.py - Done!
#     |   |-- importing - template_submod.py - Done!
#     |   - Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |-- importing - dependencies_submod.py - Done!
#     |   |-- importing - template_submod.py - Done!
#     |   - Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |-- importing - dependencies_submod.py - Done!
#     |   |-- importing - template_submod.py - Done!
#     |   - Done!
#     |
#     - Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing - template_pkg
#     |
#     |---importing - template_subpkg
#     |   |---importing - template_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |---importing - auxil_subpkg
#     |   |---importing - auxil_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |     - Done!
#     |
#     |-- importing - constants_subpkg
#     |   |---importing - constants_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |   - Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |---importing - dependencies_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |   - Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |---importing - dependencies_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |   - Done!
#     |
#     - Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing - template_pkg
#     |
#     |---importing - template_subpkg
#     |   |---importing - template_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |   - Done!
#     |
#     |---importing - auxil_subpkg
#     |   |---importing - auxil_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |   - Done!
#     |
#     |-- importing - constants_subpkg
#     |   |---importing - constants_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |   - Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |---importing - dependencies_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |   - Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |---importing - dependencies_submod.py - Done!
#     |   |---importing - template_submod.py - Done!
#     |   - Done!
#     |
#     - Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing>template_pkg
#     |
#     |---importing > template_subpkg
#     |   |---importing > template_submod.py > Done!
#     |   |---importing > template_submod.py > Done!
#     |   > Done!
#     |
#     |---importing > auxil_subpkg
#     |   |---importing > auxil_submod.py > Done!
#     |   |---importing > template_submod.py > Done!
#     |   > Done!
#     |
#     |-- importing - constants_subpkg
#     |   |---importing > constants_submod.py > Done!
#     |   |---importing > template_submod.py > Done!
#     |   > Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |---importing > dependencies_submod.py > Done!
#     |   |---importing > template_submod.py > Done!
#     |   > Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |---importing > dependencies_submod.py > Done!
#     |   |---importing > template_submod.py > Done!
#     |   > Done!
#     |
#     > Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================

# %% [raw]
# ==========================================================================
# Importing package 'template_pkg'...
# ==========================================================================
#
#     importing >> template_pkg
#     |
#     |---importing >> template_subpkg
#     |   |---importing >> template_submod.py >> Done!
#     |   |---importing >> template_submod.py >> Done!
#     |   >> Done!
#     |
#     |---importing >> auxil_subpkg
#     |   |---importing >> auxil_submod.py >> Done!
#     |   |---importing >> template_submod.py >> Done!
#     |   >> Done!
#     |
#     |-- importing >> constants_subpkg
#     |   |---importing >> constants_submod.py >> Done!
#     |   |---importing >> template_submod.py >> Done!
#     |   >> Done!
#     |
#     |-- importing >> dependencies_subpkg
#     |   |---importing >> dependencies_submod.py >> Done!
#     |   |---importing >> template_submod.py >> Done!
#     |   >> Done!
#     |
#     |-- importing - dependencies_subpkg
#     |   |---importing >> dependencies_submod.py >> Done!
#     |   |---importing >> template_submod.py >> Done!
#     |   >> Done!
#     |
#     >> Success!
#
# ==========================================================================
# Package 'template_pkg' imported sucessfully !!
# ==========================================================================
